# %%
# %load_ext autoreload
# %autoreload 2

# import ST_utils
# import train_STAligner
import sys
sys.path.append('/home/chenjn/rna2adt')

import STAligner
import train_STAligner
import ST_utils

import warnings
warnings.filterwarnings("ignore")

# # the location of R (used for the mclust clustering)
# import os
# os.environ['R_HOME'] = "/home/xzhou/anaconda3/envs/PyG/lib/R"
# os.environ['R_USER'] = "/home/xzhou/anaconda3/envs/PyG/lib/python3.8/site-packages/rpy2"
# import rpy2.robjects as robjects
# import rpy2.robjects.numpy2ri

import numpy as np
import anndata as ad
import scanpy as sc
import pandas as pd
import scipy.sparse as sp
import scipy.linalg
from scipy.sparse import csr_matrix

import torch
used_device = torch.device('cuda:6' if torch.cuda.is_available() else 'cpu')

from sklearn.metrics import adjusted_rand_score as ARI
from sklearn.metrics import normalized_mutual_info_score as NMI
from sklearn.metrics import fowlkes_mallows_score as FMI
from sklearn.metrics import silhouette_score as SC

from utils import find_resolution, find_res_label

from sklearn.cluster import KMeans

# %%
refdata = sc.read_h5ad('/home/chenjn/rna2adt/baseline/scPROTEIN/downstream_application/clinical_proteomic_application/data/ECCITE_seq_processed.h5ad')
# /home/chenjn/rna2adt/data/SCoPE2/ADT.h5ad

adata = pd.read_csv('/home/chenjn/rna2adt/output/ECCITE/embeddings.csv', index_col=0)

adata = ad.AnnData(adata)
adata.obs = refdata.obs
print(adata)

batch_key = 'donor_type'

np.unique(refdata.obs[batch_key])
# Out:
# AnnData object with n_obs × n_vars = 5401 × 128
#     obs: 'donor_type'
# array([0, 1])

# %%
Batch_list = []
adj_list = []
section_ids = np.unique(refdata.obs[batch_key]).tolist()

adata.obs_names = [str(x) + '_' + str(y) for x, y in zip(adata.obs_names, adata.obs[batch_key])]  

for section_id in section_ids:
    tmpdata = adata[adata.obs[batch_key] == section_id]
    # tmpdata.X = csr_matrix(tmpdata.X)
    # adata.var_names_make_unique(join="++")

    # make spot name unique
    # tmpdata.obs_names = [x + '_' + section_id + '_' + y for x, y in zip(tmpdata.obs_names, tmpdata.obs['celltype.l2'])]  
    # adata.obs_names = [x + '_' + section_id for x in adata.obs_names]  
    # print(tmpdata.obs_names)  
    
    # Constructing the spatial network
    ST_utils.Cal_Spatial_Net(tmpdata, k_cutoff=10, model='KNN') # the spatial network are saved in adata.uns[‘adj’]
    # ST_utils.Stats_Spatial_Net(adata) # plot the number of spatial neighbors
       
    # Normalization
    # sc.pp.highly_variable_genes(tmpdata, flavor="seurat_v3", n_top_genes=10000)
    sc.pp.normalize_total(tmpdata)
    # sc.pp.log1p(tmpdata)

    # adata = adata[:, adata.var['highly_variable']]
    adj_list.append(tmpdata.uns['adj'])
    Batch_list.append(tmpdata)
# Out:
# ------Calculating spatial graph...
# The graph contains 27670 edges, 2767 cells.
# 10.0000 neighbors per cell on average.
# ------Calculating spatial graph...
# The graph contains 26340 edges, 2634 cells.
# 10.0000 neighbors per cell on average.

# %%
# iter_comb is used to specify the order of integration. For example, (0, 1) means slice 0 will be algined with slice 1 as reference.
iter_comb = [(i, i + 1) for i in range(len(section_ids) - 1)]
print(iter_comb)

# Here, to reduce GPU memory usage, each slice is considered as a subgraph for training.
adata_af = train_STAligner.train_STAligner_subgraph(adata, verbose=True, knn_neigh = 2, 
                                                    n_epochs = 600, iter_comb = iter_comb, 
                                                    Batch_list=Batch_list, device=used_device,
                                                    margin=0.01, batch_key=batch_key,
                                                    label_key=None)
# Out:
# [(0, 1)]
# TriAE(
#   (enc_1): Linear(in_features=128, out_features=128, bias=True)
#   (enc_2): Linear(in_features=128, out_features=64, bias=True)
#   (z_layer): Linear(in_features=64, out_features=32, bias=True)
#   (dec_1): Linear(in_features=32, out_features=64, bias=True)
#   (dec_2): Linear(in_features=64, out_features=128, bias=True)
#   (x_bar_layer): Linear(in_features=128, out_features=128, bias=True)
# )
# Train with STAligner...
#   0%|                                                                                                                                                                                      | 0/100 [00:00<?, ?it/s]
# Update spot triplets at epoch 500
#   0%|                                                                                                                                                                                      | 0/100 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /data/user/chenjn/anaconda3/envs/env_STAligner/lib/python3.8/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File /data/user/chenjn/anaconda3/envs/env_STAligner/lib/python3.8/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /data/user/chenjn/anaconda3/envs/env_STAligner/lib/python3.8/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'celltype'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 6
#       3 print(iter_comb)
#       5 # Here, to reduce GPU memory usage, each slice is considered as a subgraph for training.
# ----> 6 adata_af = train_STAligner.train_STAligner_subgraph(adata, verbose=True, knn_neigh = 2,
#       7                                                     n_epochs = 600, iter_comb = iter_comb,
#       8                                                     Batch_list=Batch_list, device=used_device,
#       9                                                     margin=0.01, batch_key=batch_key,
#      10                                                     label_key='celltype')
#
# File /data/user/chenjn/rna2adt/train_STAligner.py:385, in train_STAligner_subgraph(adata, hidden_dims, n_epochs, lr, key_added, gradient_clipping, weight_decay, margin, verbose, random_seed, iter_comb, knn_neigh, Batch_list, device, batch_key, label_key)
#     377             negative_list.append(cellname_by_batch_dict[batchname_list[anchor]][np.random.randint(section_size)])
#     378         # anchor_list.append(anchor)
#     379         # positive_spot = mnn_dict[batch_pair_name][anchor][0]
#     380         # positive_list.append(positive_spot)
#     381         # section_size = len(cellname_by_batch_dict[batchname_list[anchor]])
#     382         # negative_list.append(
#     383         #     cellname_by_batch_dict[batchname_list[anchor]][np.random.randint(section_size)])
# --> 385 type_as_dict = dict(zip(list(batch_pair.obs_names), list(batch_pair.obs[label_key])))
#     386 anchor_types = list(map(lambda _: type_as_dict[_], anchor_list))
#     387 positive_types = list(map(lambda _: type_as_dict[_], positive_list))
#
# File /data/user/chenjn/anaconda3/envs/env_STAligner/lib/python3.8/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File /data/user/chenjn/anaconda3/envs/env_STAligner/lib/python3.8/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'celltype'

# %%
adata1 = ad.AnnData(adata_af.obsm['STAligner'], obs=adata_af.obs)

# %%
sc.pp.neighbors(adata1)
sc.tl.louvain(adata1)
adata1.obs['louvain_res'] = find_res_label(adata1, len(np.unique(adata.obs['celltype'])))

# %%
sc.tl.umap(adata1)
sc.pl.umap(adata1, color=[batch_key, 'celltype'], ncols=2, wspace=0.4, show=True)
sc.pl.umap(adata1, color=['louvain', 'louvain_res'], ncols=2, wspace=0.4, show=True)

print(ARI(adata1.obs['louvain'], adata1.obs['celltype']))
print(NMI(adata1.obs['louvain'], adata1.obs['celltype']))
print(FMI(adata1.obs['louvain'], adata1.obs['celltype']))
print()
print(ARI(adata1.obs['louvain_res'], adata.obs['celltype']))
print(NMI(adata1.obs['louvain_res'], adata.obs['celltype'])) 
print(FMI(adata1.obs['louvain_res'], adata.obs['celltype']))
# Out:
# -0.0030055662815798964
# 0.0017736399784332368
# 0.32960732395100567
#
# -0.0009015223715137946
# 4.353903399926134e-06
# 0.5640120405845451
